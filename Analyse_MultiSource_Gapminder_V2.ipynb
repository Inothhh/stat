# %% [markdown]
# # 📊 Analyse Descriptive Multi-source (Gapminder + continents)
# Ce notebook combine les données d'espérance de vie, de revenus et de continents pour produire des analyses détaillées.

# %%
#  Import des bibliothèques
import pandas as pd
import matplotlib.pyplot as plt
import json
# %matplotlib inline

# %%
#  Chargement des fichiers CSV + JSON
life_df = pd.read_csv('data_gapminder/life_expectancy_years.csv')
income_df = pd.read_csv('data_gapminder/income.csv')
with open('data_gapminder/country_continent.json') as f:
    country_continent = json.load(f)

# %%
#  Aperçu des datasets
display(life_df.head())
display(income_df.head())
# Out:
#                 country  1800  1801  1802  1803  1804  1805  1806  1807  1808  \
# 0           Afghanistan  28.2  28.2  28.2  28.2  28.2  28.2  28.1  28.1  28.1
# 1                Angola  27.0  27.0  27.0  27.0  27.0  27.0  27.0  27.0  27.0
# 2               Albania  35.4  35.4  35.4  35.4  35.4  35.4  35.4  35.4  35.4
# 3               Andorra   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  United Arab Emirates  30.7  30.7  30.7  30.7  30.7  30.7  30.7  30.7  30.7
#
#    ...  2091  2092  2093  2094  2095  2096  2097  2098  2099  2100
# 0  ...  75.5  75.7  75.8  76.0  76.1  76.2  76.4  76.5  76.6  76.8
# 1  ...  78.8  79.0  79.1  79.2  79.3  79.5  79.6  79.7  79.9  80.0
# 2  ...  87.4  87.5  87.6  87.7  87.8  87.9  88.0  88.2  88.3  88.4
# 3  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  ...  82.4  82.5  82.6  82.7  82.8  82.9  83.0  83.1  83.2  83.3
#
# [5 rows x 302 columns]
#                 country  1800  1801  1802  1803  1804  1805  1806  1807  1808  \
# 0           Afghanistan   683   683   683   683   683   683   683   683   683
# 1                Angola   700   702   705   709   711   714   718   721   725
# 2               Albania   755   755   755   755   755   756   756   756   756
# 3               Andorra  1360  1360  1360  1360  1370  1370  1370  1370  1380
# 4  United Arab Emirates  1130  1130  1140  1140  1150  1150  1160  1160  1160
#
#    ...   2041   2042   2043   2044   2045   2046   2047   2048   2049   2050
# 0  ...   2690   2750   2810   2870   2930   2990   3060   3120   3190   3260
# 1  ...   8000   8170   8350   8530   8710   8900   9090   9280   9480   9690
# 2  ...  25.1k  25.6k  26.2k  26.7k  27.3k  27.9k  28.5k  29.1k  29.7k  30.4k
# 3  ...  68.9k  70.4k  71.9k  73.4k    75k  76.6k  78.3k    80k  81.7k  83.4k
# 4  ...   101k   103k   105k   107k   110k   112k   114k   117k   119k   122k
#
# [5 rows x 252 columns]

# %%
#  Transformation des jeux de données (passage en long format)
life_long = life_df.melt(id_vars='country', var_name='year', value_name='life_expectancy')
income_long = income_df.melt(id_vars='country', var_name='year', value_name='income')

# 🔗 Fusion des deux jeux
merged_df = pd.merge(life_long, income_long, on=['country', 'year'])

# %%
#  Ajout des continents via le JSON
merged_df['continent'] = merged_df['country'].map(country_continent)
merged_df['year'] = merged_df['year'].astype(int)
merged_df.dropna(inplace=True)  # On supprime les lignes avec pays sans continent

# %%
#  Évolution de l'espérance de vie moyenne par continent
pivot_life = merged_df.groupby(['continent', 'year'])['life_expectancy'].mean().unstack(0)
pivot_life.plot(figsize=(10,6), marker='o')
plt.title("Espérance de vie moyenne par continent")
plt.ylabel("Espérance de vie")
plt.xlabel("Année")
plt.grid(True)
plt.legend(title='Continent')

# %%
#  Évolution du revenu moyen par continent
merged_df['income'] = pd.to_numeric(merged_df['income'], errors='coerce')

pivot_income = merged_df.groupby(['continent', 'year'])['income'].mean().unstack(0)

pivot_income.plot(figsize=(10,6), marker='s')
plt.title("Revenu moyen par continent")
plt.ylabel("Revenu par habitant (USD)")
plt.xlabel("Année")
plt.grid(True)
plt.legend(title='Continent')

# %%
#  Corrélation entre espérance de vie et revenu (ex : année 2000)
df_2000 = merged_df[merged_df['year'] == 2000]
plt.figure(figsize=(8,6))
for cont in df_2000['continent'].unique():
    subset = df_2000[df_2000['continent'] == cont]
    plt.scatter(subset['income'], subset['life_expectancy'], label=cont)

plt.xscale('log')
plt.xlabel("Revenu par habitant (log scale)")
plt.ylabel("Espérance de vie")
plt.title("Espérance de vie vs Revenu (année 2000)")
plt.legend()
plt.grid(True)

# %%
#  Pays avec espérance de vie la plus haute et la plus basse chaque année
summary = merged_df.groupby('year').apply(lambda d: pd.Series({
    'Max LifeExp': d.loc[d['life_expectancy'].idxmax(), 'country'],
    'Min LifeExp': d.loc[d['life_expectancy'].idxmin(), 'country']
})).reset_index()
summary.head()
# Out:
# C:\Users\white\AppData\Local\Temp\ipykernel_40924\2769518141.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   summary = merged_df.groupby('year').apply(lambda d: pd.Series({
#    year Max LifeExp Min LifeExp
# 0  1800     Iceland       Yemen
# 1  1801     Finland       Yemen
# 2  1802     Denmark       Yemen
# 3  1803     Denmark     Iceland
# 4  1804     Denmark       Yemen

# %%
#  Top 10 des pays avec le plus de revenus en 2022
top_10_revenus = income_df[['country', '2022']].sort_values(by='2022', ascending=False).head(10)
top_10_revenus.reset_index(drop=True, inplace=True)
top_10_revenus
# Out:
#                     country   2022
# 0                      Iraq   9900
# 1                     Qatar  95.5k
# 2  Central African Republic    944
# 3                   Jamaica   9370
# 4               El Salvador   9040
# 5                 Guatemala   9010
# 6                   Namibia   8820
# 7                   Vietnam   8760
# 8               Philippines   8700
# 9                  Eswatini   8660

# %%
#  Pays avec le revenu le plus élevé chaque année
years = income_df.columns[1:]
top_each_year = income_df.set_index('country')[years].idxmax()
top_country_counts = top_each_year.value_counts()
top_country_counts.head(1)
# Out:
# United Kingdom    69
# Name: count, dtype: int64

# %%
bottom_each_year = income_df.set_index('country')[years].idxmin()
bottom_country_counts = bottom_each_year.value_counts()
bottom_country_counts.head(1)
# Out:
# North Korea    65
# Name: count, dtype: int64

# %%
# Conversion : on transforme '25.1k' → 25100.0
def clean_income(df):
    for col in df.columns[1:]:
        df[col] = df[col].astype(str).str.replace('k', '000').str.replace('.', '', regex=False)
        df[col] = pd.to_numeric(df[col], errors='coerce')
    return df

# Appliquer le nettoyage
income_clean = income_df.copy()
income_clean = clean_income(income_clean)

# Refaire l'opération avec des nombres
gap = income_clean[years].max() - income_clean[years].min()
gap = gap.reset_index()
gap.columns = ['year', 'gap']
gap['year'] = gap['year'].astype(int)

# Affichage
plt.figure(figsize=(10, 6))
plt.plot(gap['year'], gap['gap'], marker='o', color='blue')
plt.title("Écart entre le pays le plus riche et le plus pauvre")
plt.xlabel("Année")
plt.ylabel("Écart de revenu (USD)")
plt.grid(True)
plt.show()

# %%
# Nettoyage de la colonne '2022' pour convertir 'k' en mille et transformer en float
revenus_2022 = income_df['2022'].astype(str).str.replace('k', '000').str.replace('.', '', regex=False)
revenus_2022 = pd.to_numeric(revenus_2022, errors='coerce')  # ignore les erreurs si certaines valeurs sont NaN

# Calculs
moyenne = revenus_2022.mean()
mediane = revenus_2022.median()
mode = revenus_2022.mode().values[0]

# Affichage
print(f"Moyenne : {moyenne:.2f} USD")
print(f"Médiane : {mediane:.2f} USD")
print(f"Mode : {mode} USD")
# Out:
# Moyenne : 171083.27 USD
# Médiane : 119000.00 USD
# Mode : 132000 USD

# %%
plt.hist(revenus_2022, bins=30, color='skyblue', edgecolor='black')
plt.title("Histogramme des revenus en 2022")
plt.xlabel("Revenus (USD)")
plt.ylabel("Nombre de pays")
plt.grid(True)
plt.show()

# %%
# Liste des années à analyser
annees = ['1805', '1900', '1945', '2000', '2022']

# Nettoyage des colonnes pour enlever les 'k' et convertir en float
data_boxplot = []
for annee in annees:
    cleaned = income_df[annee].astype(str).str.replace('k', '000').str.replace('.', '', regex=False)
    numeric = pd.to_numeric(cleaned, errors='coerce')
    data_boxplot.append(numeric.dropna())

# Création du boxplot
plt.boxplot(data_boxplot, labels=annees)
plt.title("BoxPlot des revenus par année")
plt.xlabel("Année")
plt.ylabel("Revenus (USD)")
plt.grid(True)
plt.show()
# Out:
# C:\Users\white\AppData\Local\Temp\ipykernel_40924\2066459138.py:12: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data_boxplot, labels=annees)
